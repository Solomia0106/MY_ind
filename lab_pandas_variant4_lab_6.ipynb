# %% [markdown]
# <a href="https://colab.research.google.com/github/Solomia0106/MY_ind/blob/main/lab_pandas_variant4_lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторна робота: Аналіз даних з Pandas
#
# **Варіант 4**
# Набір даних: `police_project.csv` / Stanford Open Policing Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Якщо файл є на компʼютері, завантаж його в Colab і заміни шлях на /content/police_project.csv
# Якщо файлу немає, Colab спробує відкрити набір даних з GitHub.
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
police = pd.read_csv(url, sep='\t')

police.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## Загальні завдання для всіх варіантів

# %%
# 1-2. Завантаження набору даних і перші 5 записів
police.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# 3. Скільки рядків і стовпців у таблиці?
police.shape
# Out:
# (4622, 5)

# %%
# 4. Назви стовпців
police.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# 5. Типи даних у стовпцях
police.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# 6. Кількість унікальних значень у кожному стовпці
police.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
# 7. Кількість пропущених значень
police.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
police['quantity'].hist(bins=10)

plt.title("Розподіл quantity")
plt.xlabel("Кількість")
plt.ylabel("Частота")

plt.show()

# %% [markdown]
# 1. Аналіз кількості товарів

# %%
police['quantity'].value_counts()
# Out:
# quantity
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: count, dtype: int64

# %% [markdown]
# 2. Побудова гістограми quantity

# %%
police['quantity'].hist(bins=10)

plt.title("Розподіл quantity")
plt.xlabel("Кількість")
plt.ylabel("Частота")

plt.show()

# %% [markdown]
# 3. Найпопулярніші товари

# %%
police['item_name'].value_counts().head(10)
# Out:
# item_name
# Chicken Bowl                    726
# Chicken Burrito                 553
# Chips and Guacamole             479
# Steak Burrito                   368
# Canned Soft Drink               301
# Chips                           211
# Steak Bowl                      211
# Bottled Water                   162
# Chicken Soft Tacos              115
# Chips and Fresh Tomato Salsa    110
# Name: count, dtype: int64

# %% [markdown]
# 4. Побудова графіка популярних товарів

# %%
police['item_name'].value_counts().head(10).plot(kind='bar')

plt.title("Популярні товари")
plt.xlabel("Товар")
plt.ylabel("Кількість")

plt.show()
