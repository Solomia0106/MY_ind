# %% [markdown]
# <a href="https://colab.research.google.com/github/Solomia0106/MY_ind/blob/main/lab_5_kazymyr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Джибуті
#
# ## Загальна інформація
#
# **Джибуті** — держава у Східній Африці.
#
# ### Основні дані
#
# | Параметр | Значення |
# |---|---|
# | Столиця | Джибуті |
# | Площа | 23 200 км² |
# | Населення | близько 1 млн |
# | Мова | французька, арабська |
# | Валюта | франк Джибуті |
#
# ---
#
# ## Державний устрій
#
# Джибуті є президентською республікою.
#
# ## Відомі місця
#
# 1. Озеро Ассаль
# 2. Затока Таджура
# 3. Національний парк Дей
#
# ## Цікаві факти
#
# - Країна має дуже спекотний клімат
# - Розташована біля Червоного моря
# - Має важливий морський порт
#
# ## Гіперпосилання
#
# [Wikipedia Djibouti](https://uk.wikipedia.org/wiki/Джибуті)
#
# ---
#
# ## Прапор Джибуті
#
# <svg width="300" height="180">
# <rect width="300" height="90" fill="skyblue"/>
# <rect y="90" width="300" height="90" fill="green"/>
# <polygon points="0,0 130,90 0,180" fill="white"/>
# <circle cx="45" cy="90" r="18" fill="red"/>
# </svg>

# %%
def task_4():

    text = input("Введіть числа через пробіл: ")

    try:
        numbers = list(map(int, text.split()))

    except:
        print("Помилка! Введіть тільки числа.")
        return

    swaps = 0

    for i in range(len(numbers)):

        for j in range(0, len(numbers) - i - 1):

            if numbers[j] > numbers[j + 1]:

                numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j]

                swaps += 1

    print("Відсортований список:", numbers)
    print("Було виконано", swaps, "переставлень")

# %%
task_4()
# Out:
# Введіть числа через пробіл: 5 6 23 8 12 5
# Відсортований список: [5, 5, 6, 8, 12, 23]
# Було виконано 6 переставлень

# %%
task_4()
# Out:
# Введіть числа через пробіл: 7 3 1 7 4 2 8 2
# Відсортований список: [1, 2, 2, 3, 4, 7, 7, 8]
# Було виконано 14 переставлень

# %%
task_4()
# Out:
# Введіть числа через пробіл: 5 7 hello
# Помилка! Введіть тільки числа.
